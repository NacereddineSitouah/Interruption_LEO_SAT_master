# %%
import os 
import re
import time
import pandas as pd
import multiprocessing as mp
import numpy as np
import dask.dataframe as dd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from collections import OrderedDict
import torch.nn.functional as F
from torch import nn
import math
import matplotlib.pyplot as plt

from statistics import mean

import torch
from torch import optim
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
a=time.time()
path0 ='/kaggle/input/'
df = pd.read_csv(path0+"corrected2/FinaldatasetN1.csv")
print('improt time '+str(time.time()-a))

a=time.time()
#df=df[['channel','Next_Current_diff','Next_Pre_diff','size', 'packet_type','DataQueueLen','lossRate','SNext_Current_diff','SNext_Pre_diff','snir','throughput','Flow Bytes_s','Flow Packets_s','meanT_b_2P','minT_b_2P','maxT_b_2P','label']]     
#df=df[['channel','Next_Current_diff','Next_Pre_diff','size', 'packet_type','lossRate','SNext_Current_diff','SNext_Pre_diff','snir','throughput','Flow Bytes_s','Flow Packets_s','meanT_b_2P','minT_b_2P','maxT_b_2P','label']]     
df=df[['channel','Next_Current_diff','Next_Pre_diff','size','packet_type','SNext_Current_diff','SNext_Pre_diff','snir','throughput','Flow Bytes_s','Flow Packets_s','meanT_b_2P','minT_b_2P','maxT_b_2P','label']]     
#df=df[['channel','Next_Current_diff','Next_Pre_diff','size','packet_type','SNext_Current_diff','SNext_Pre_diff','snir','Flow Bytes_s','Flow Packets_s','meanT_b_2P','minT_b_2P','maxT_b_2P','label']]     


#df=df.to_numpy()
#df_Normal=df[200000:354961].copy()
df_Normal=df[0:354961].copy()

#print(df_Normal[0][1])
#print(df_Normal[-1][1])
df_UDP1=df[354961:763730].copy()
#print(df_UDP1[0][1])
#print(df_UDP1[-1][1])
df_UDP2=df[763730:1573000].copy()
#print(df_UDP2[0][1])
#print(df_UDP2[-1][1])
#df_jam1=df[1573000:1696992].copy()
df_jam1=df[1573000:1696992].copy()

#print(df_jam1[0][1])
#print(df_jam1[-1][1])
df_jam2=df[1696992:2714727].copy()
#print(df_jam2[0][1])
#print(df_jam2[-1][1])
df_pluies=df[2714727:-1].copy()
#print(df_pluies[0][1])
#print(df_pluies[-1][1])
del(df)

X=df_Normal.drop(columns = ['label']).copy()
y=df_Normal[['label']].copy()
#print(y.columns)
X1=df_UDP1.drop(columns = ['label']).copy()
y1=df_UDP1[['label']].copy()
X2=df_UDP2.drop(columns = ['label']).copy()
y2=df_UDP2[['label']].copy()
X3=df_jam1.drop(columns = ['label']).copy()
y3=df_jam1[['label']].copy()
X4=df_jam2.drop(columns = ['label']).copy()
y4=df_jam2[['label']].copy()
X5=df_pluies.drop(columns = ['label']).copy()
y5=df_pluies[['label']].copy()

train=0.7
#train=0.01

del(df_Normal)
del(df_UDP1)
del(df_UDP2)
del(df_jam1)
del(df_jam2)
del(df_pluies)


xcol=X.columns
ycol=y.columns


X_train, X_rem, y_train, y_rem = train_test_split(X,y, train_size=train,shuffle=False)
X_train1, X_rem1, y_train1, y_rem1 = train_test_split(X1,y1, train_size=train,shuffle=False)
X_train2, X_rem2, y_train2, y_rem2 = train_test_split(X2,y2, train_size=train,shuffle=False)
X_train3, X_rem3, y_train3, y_rem3 = train_test_split(X3,y3, train_size=train,shuffle=False)
X_train4, X_rem4, y_train4, y_rem4 = train_test_split(X4,y4, train_size=train,shuffle=False)
X_train5, X_rem5, y_train5, y_rem5 = train_test_split(X5,y5, train_size=train,shuffle=False)

#validation=0.5
#X_valid, X_rem, y_valid, y_rem = train_test_split(X_rem,y_rem, test_size=validation,shuffle=False)
#X_valid1, X_rem1, y_valid1, y_rem1 = train_test_split(X_rem1,y_rem1, test_size=validation,shuffle=False)
#X_valid2, X_rem2, y_valid2, y_rem2 = train_test_split(X_rem2,y_rem2, test_size=validation,shuffle=False)
#X_valid3, X_rem3, y_valid3, y_rem3 = train_test_split(X_rem3,y_rem3, test_size=validation,shuffle=False)
#X_valid4, X_rem4, y_valid4, y_rem4= train_test_split(X_rem4,y_rem4, test_size=validation,shuffle=False)
#X_valid5, X_rem5, y_valid5, y_rem5 = train_test_split(X_rem5,y_rem5, test_size=validation,shuffle=False)

#validation=0.65
#X_valid, X_rem, y_valid, y_rem = train_test_split(X_rem,y_rem, test_size=validation,shuffle=False)
#X_valid1, X_rem1, y_valid1, y_rem1 = train_test_split(X_rem1,y_rem1, test_size=validation,shuffle=False)
#X_valid2, X_rem2, y_valid2, y_rem2 = train_test_split(X_rem2,y_rem2, test_size=validation,shuffle=False)
#X_valid3, X_rem3, y_valid3, y_rem3 = train_test_split(X_rem3,y_rem3, test_size=validation,shuffle=False)
#X_valid4, X_rem4, y_valid4, y_rem4= train_test_split(X_rem4,y_rem4, test_size=validation,shuffle=False)
#X_valid5, X_rem5, y_valid5, y_rem5 = train_test_split(X_rem5,y_rem5, test_size=validation,shuffle=False)



X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=0.57,shuffle=False)
X_valid1, X_test1, y_valid1, y_test1 = train_test_split(X_rem1,y_rem1, test_size=0.57,shuffle=False)
X_valid2, X_test2, y_valid2, y_test2 = train_test_split(X_rem2,y_rem2, test_size=0.57,shuffle=False)
X_valid3, X_test3, y_valid3, y_test3 = train_test_split(X_rem3,y_rem3, test_size=0.57,shuffle=False)
X_valid4, X_test4, y_valid4, y_test4 = train_test_split(X_rem4,y_rem4, test_size=0.57,shuffle=False)
X_valid5, X_test5, y_valid5, y_test5 = train_test_split(X_rem5,y_rem5, test_size=0.57,shuffle=False)


X_train=np.concatenate((X_train, X_train1, X_train2,X_train3, X_train4,X_train5))
X_valid=np.concatenate((X_valid, X_valid1, X_valid2,X_valid3, X_valid4,X_valid5))
X_test=np.concatenate((X_test, X_test1, X_test2,X_test3, X_test4,X_test5))

y_train=np.concatenate((y_train, y_train1, y_train2,y_train3, y_train4,y_train5))
y_valid=np.concatenate((y_valid, y_valid1, y_valid2,y_valid3, y_valid4,y_valid5))
y_test=np.concatenate((y_test, y_test1, y_test2,y_test3, y_test4,y_test5))

X_train = pd.DataFrame(X_train, columns= xcol)
X_valid = pd.DataFrame(X_valid, columns= xcol)
X_test = pd.DataFrame(X_test, columns= xcol)

y_train = pd.DataFrame(y_train, columns= ycol)
y_valid = pd.DataFrame(y_valid, columns= ycol)
y_test = pd.DataFrame(y_test, columns= ycol)

#########333
n=0
u=0
p=0
j=0
t=0
# Out:
# /kaggle/input/corrected2/FinaldatasetN1.csv
# improt time 31.79211711883545

# %%
y_train2=y_train.to_numpy()
y_train22=y_valid.to_numpy()
y_train222=y_test.to_numpy()
print(y_train2)

print(len(y_train2))
print('-------------------------')
for x ,i in enumerate(y_train2):
    
    if(i[-1]=='Normal'):
        n+=1
    if(i[-1]=='DDOS_UDP_FLOOD'):
        u+=1
        t+=1
    if(i[-1]=='PLUIES_ET_ORAGES'):
        p+=1 
        #n+=1
        #t+=1
    if(i[-1]=='BROUILLAGE_Trafic'):
        #u+=1
        j+=1
        t+=1

print('normal {0} and of {1}'.format(n*100/len(y_train),t*100/len(y_train)))
print('udp {0} and of {1}'.format(u*100/len(y_train),u*100/len(y_train)))
print('pluies {0} and of {1}'.format(p*100/len(y_train),p*100/len(y_train)))
print('jam {0} and of {1}'.format(j*100/len(y_train),j*100/len(y_train)))


n=0;u=0;p=0;j=0;t=0

print(len(y_train22))
print('-------------------------')
for x ,i in enumerate(y_train22):
    
    if(i[-1]=='Normal'):
        n+=1
    if(i[-1]=='DDOS_UDP_FLOOD'):
        u+=1
        t+=1
    if(i[-1]=='PLUIES_ET_ORAGES'):
        p+=1 
        #n+=1
        #t+=1
    if(i[-1]=='BROUILLAGE_Trafic'):
        #u+=1
        j+=1
        t+=1

print('normal {0} and of {1}'.format(n*100/len(y_train22),t*100/len(y_train22)))
print('udp {0} and of {1}'.format(u*100/len(y_train22),u*100/len(y_train22)))
print('pluies {0} and of {1}'.format(p*100/len(y_train22),p*100/len(y_train22)))
print('jam {0} and of {1}'.format(j*100/len(y_train22),j*100/len(y_train22)))

n=0;u=0;p=0;j=0;t=0

print(len(y_train222))
print('-------------------------')
for x ,i in enumerate(y_train222):
    
    if(i[-1]=='Normal'):
        n+=1
    if(i[-1]=='DDOS_UDP_FLOOD'):
        u+=1
        t+=1
    if(i[-1]=='PLUIES_ET_ORAGES'):
        p+=1 
        #n+=1
        #t+=1
    if(i[-1]=='BROUILLAGE_Trafic'):
        #u+=1
        j+=1
        t+=1

print('normal {0} and of {1}'.format(n*100/len(y_train222),t*100/len(y_train222)))
print('udp {0} and of {1}'.format(u*100/len(y_train222),u*100/len(y_train222)))
print('pluies {0} and of {1}'.format(p*100/len(y_train222),p*100/len(y_train222)))
print('jam {0} and of {1}'.format(j*100/len(y_train222),j*100/len(y_train222)))

########

print(int(len(y_train))+int(len(y_valid))+int(len(y_test)))
print('creating input data time '+str(time.time()-a))



a-time.time()
X_train1=X_train.values
y_train1=y_train.values
#X_train1=X_train1.astype(float)

torch_tensor = torch.tensor(X_train1)
#torch_tensor[torch_tensor != torch_tensor]=float(0)
t=[]
test=0
test0=0

for j in y_train1:
    i=j[0]
#    print(i)
    if (i=='Normal'):
        t.append(int(0))
        test0+=1
    #t.append(int(1))
    if (i=='DDOS_UDP_FLOOD'):
        t.append(int(1))
    if (i=='PLUIES_ET_ORAGES'):
        t.append(int(2))
        test+=1
    if (i=='BROUILLAGE_Trafic'):
        t.append(int(3))
print(test)
labels = torch.LongTensor(t)
#print(torch_tensor[-1])
#print(labels[-1])
print(labels)
#print(df_label)
#print(labels.shape)

#df00 = pd.read_csv(path0+"small/testbed3/Dataset_S03Filtrer.csv")
#bigX = df00[['Next_Current_diff','Next_Pre_diff','SNext_Current_diff','SNext_Pre_diff','rcvdPK','duration(ms)','droppedPKWrongPort','sentPK','size','channel','throughput']]         
#bigY = df00['label']
bigX = X_valid
#[['Next_Current_diff','Next_Pre_diff','SNext_Current_diff','SNext_Pre_diff','rcvdPK','duration(ms)','droppedPKWrongPort','sentPK','size','throughput']]  ,'channel'       
bigY = y_valid['label']
#print(bigY)
X_valid1=bigX.values
y_valid1=bigY.values

#X_valid1=X_test.values
#y_valid1=y_test.values
#X_train1=X_train1.astype(float)

vtorch_tensor = torch.tensor(X_valid1)
v=[]

for i in y_valid1:
    #i=j[0]
    #print(i)
    if (i=='Normal'):
        v.append(int(0))
        #t.append(int(1))
    if (i=='DDOS_UDP_FLOOD'):
        v.append(int(1))
    if (i=='PLUIES_ET_ORAGES'):
        v.append(int(2))
    if (i=='BROUILLAGE_Trafic'):
        v.append(int(3))

vlabels = torch.LongTensor(v)


X_test1=X_test.values
y_test1=y_test.values

#X_train1=X_train1.astype(float)

ttorch_tensor = torch.tensor(X_test1)

#torch_tensor[torch_tensor != torch_tensor]=float(0)
t=[]

for j in y_test1:
    i=j[0]
#    print(i)
    if (i=='Normal'):
        t.append(int(0))
        #t.append(int(1))
    if (i=='DDOS_UDP_FLOOD'):
        t.append(int(1))
    if (i=='PLUIES_ET_ORAGES'):
        t.append(int(2))
    if (i=='BROUILLAGE_Trafic'):
        t.append(int(3))

tlabels = torch.LongTensor(t)
#print(torch_tensor[-1])
#print(labels[-1])
print(len(labels))
print(len(vlabels))
print(len(tlabels))

del(X)
del(y)
del(X1)
del(y1)
del(X2)
del(y2)
del(X3)
del(y3)
del(X4)
del(y4)
del(X5)
del(y5)
del(X_train1); del(X_train2);del(X_train3); del(X_train4);del(X_train5)
del(y_train1); del(y_train2);del(y_train3); del(y_train4);del(y_train5)
del(y_rem);del(y_rem1); del(y_rem2);del(y_rem3); del(y_rem4);del(y_rem5)
del(X_rem);del(X_rem1); del(X_rem2);del(X_rem3); del(X_rem4);del(X_rem5)

#X_rem1, y_train1, y_rem1
del(X_train)
del(X_valid)
del(X_valid1); del(X_valid2);del(X_valid3); del(X_valid4);del(X_valid5)
del(y_valid1); del(y_valid2);del(y_valid3); del(y_valid4);del(y_valid5)


del(X_test)
del(X_test1); del(X_test2);del(X_test3); del(X_test4);del(X_test5)
del(y_test1); del(y_test2);del(y_test3); del(y_test4);del(y_test5)

del(y_train)
del(y_valid)
del(y_test)
del(t)
del(v)

inputs=torch_tensor[:,:] 
labels1=labels[:]
del(torch_tensor)
del(labels)
#print(len(inputs))
#print(len(labels1))
vinputs =vtorch_tensor[:,:]
vlabels1=vlabels[:]
del(vtorch_tensor)
del(vlabels)
tinputs =ttorch_tensor[:,:] 
tlabels1=tlabels[:]
del(ttorch_tensor)
del(tlabels)

print(sum(labels1))
print(sum(vlabels1))
print(sum(tlabels1))

 
print(time.time()-a)
# Out:
# [['Normal']
#  ['Normal']
#  ['Normal']
#  ...
#  ['Normal']
#  ['Normal']
#  ['Normal']]
# 2381331
# -------------------------
# normal 54.43875714883819 and of 34.5121278814243
# udp 29.252590253097953 and of 29.252590253097953
# pluies 11.049114969737513 and of 11.049114969737513
# jam 5.259537628326344 and of 5.259537628326344
# 438845
# -------------------------
# normal 54.98524535997904 and of 34.5310986794882
# udp 29.281864895350296 and of 29.281864895350296
# pluies 10.483655960532761 and of 10.483655960532761
# jam 5.249233784137908 and of 5.249233784137908
# 581729
# -------------------------
# normal 54.595352818924276 and of 34.50438262489922
# udp 29.250561687658685 and of 29.250561687658685
# pluies 10.900264556176502 and of 10.900264556176502
# jam 5.253820937240536 and of 5.253820937240536
# 3401905
# creating input data time 5.89917254447937
# 263116
# tensor([0, 0, 0,  ..., 0, 0, 0])
# 2381331
# 438845
# 581729
# tensor(1598574)
# tensor(289624)
# tensor(388668)
# 32.16007995605469

# %%
torch.set_default_dtype(torch.float64)

from torch import nn, optim
import torch.nn.functional as F

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 
# input_size = 784 # 28x28
num_classes = 4
#num_epochs = 2
batch_size = 500
learning_rate = 0.01

input_size = 14
sequence_length = 28
hidden_size = 132
num_layers = 2

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.GRU(input_size, hidden_size, num_layers,batch_first=True)
        # -> x needs to be: (batch_size, seq, input_size)
        
        # or:
        #self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        #self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        # Set initial hidden states (and cell states for LSTM)
        x=x.view(-1,1,14)
        #print(x.shape)
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        #c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        
        # x: (n, 28, 28), h0: (2, n, 128)
        
        # Forward propagate RNN
        out, _ = self.rnn(x, h0)  
        # or:
        #out, _ = self.lstm(x, (h0,c0))  
        
        # out: tensor of shape (batch_size, seq_length, hidden_size)
        # out: (n, 28, 128)
        
        # Decode the hidden state of the last time step
        out = out[:, -1, :]
        # out: (n, 128)
         
        #out = self.fc(out)
        x = F.log_softmax(self.fc(out), dim=1)
        # out: (n, 10)
        return x

model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)
 
       
Fonction_de_perte = nn.NLLLoss()

optimizer = optim.Adam(model.parameters(), lr=0.003)

#indices = [0,3, 299:303]

# %%
#labels1=labels[loc]
a=time.time()
#inputs=torch_tensor[:,:].to(device) 
##labels1=labels[:].to(device)
#print(len(inputs))
#print(len(labels1))
#vinputs =vtorch_tensor[:,:].to(device)
#vlabels1=vlabels[:].to(device)
no_learning=0
epochs = 200
valid_loss=0
accuracy=0
valid_loss_min=np.Inf
batch_size = 500

####33  !!!!!!!!!! This shit cost alot of time ----> do not use it 
#b=time.time()
#with torch.no_grad():
   # for i, x in enumerate(vinputs):
       # x2=x[None,:]
       # output = torch.exp(model(x2))
       # l2=vlabels1[i][None]
       # test_loss+=Fonction_de_perte(output, l2)
     #   output = torch.exp(output)
      #  top_p , top_c = output.topk(1, dim=1)
     #   equals = top_c==vlabels1[i].view(*top_c.shape)
    #    accuracy += torch.mean(equals.type(torch.FloatTensor))

   # tain_losses.append(running_loss/len(inputs))
   # test_losses.append(test_loss/len(vinputs))
   # print ('test accuracy :{0}, test loss : {2} ,  time {1} '.format(accuracy*100/len(vinputs) , time.time()-b ,test_loss/len(vinputs) ))

######## ---> use this :) 
b=time.time()
with torch.no_grad():
    output = torch.exp(model(vinputs))
    valid_loss=Fonction_de_perte(output, vlabels1)
top_p , top_c = output.topk(1, dim=1)
del(output)
propabilities= torch.mean(top_p.type(torch.FloatTensor))*100
equals = top_c==vlabels1.view(*top_c.shape)
accuracy = torch.mean(equals.type(torch.FloatTensor))
#print ('valid accuracy :{0:.8f} with total prob : {3:.8f} and  valid loss : {2:.8f} ,  time {1:.6f} '.format(accuracy*100 , time.time()-b ,test_loss,propabilities))
print ('Epoch  : valid accuracy :{0:.8f} with total prob : {1:.8f} '.format(accuracy*100  ,propabilities))

####
#print(inputs.shape[0])
train_losses=[]
valid_losses=[]
for e in range(epochs):
    c=time.time()
    running_loss = 0
    #for i, x in enumerate(inputs):
    for i in range(0,inputs.size()[0], batch_size):
        optimizer.zero_grad()
        optimizer.zero_grad()

        #indices = [i:i+batch_size]
        #print(i+batch_size)
        batch_x, batch_y = inputs[i:i+batch_size], labels1[i:i+batch_size]
        
        #x2=x[None,:]
        output = model.forward(batch_x)
        
        #output = model.forward(x2)
        #l2=labels1[i][None]
        #print(l2)
        #loss = Fonction_de_perte(output, l2)
        loss = Fonction_de_perte(output, batch_y)
      
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

    else:
        accuracy=0
        #print(l2)
       
        b=time.time()
        with torch.no_grad():
            ##
            #with torch.no_grad():
            #for i, x in enumerate(vinputs):
             #   x2=x[None,:]
              #  output = torch.exp(model(x2))
               # l2=vlabels1[i][None]
                #valid_loss1+=Fonction_de_perte(output, l2)
            #test_loss=test_loss/len(vinputs)
            ##
                
            model.eval()
            output = torch.exp(model(vinputs))
            valid_loss=Fonction_de_perte(output, vlabels1)
        top_p , top_c = output.topk(1, dim=1)
        del(output)
        propabilities= torch.mean(top_p.type(torch.FloatTensor))*100
        equals = top_c==vlabels1.view(*top_c.shape)
        accuracy = torch.mean(equals.type(torch.FloatTensor))
        model.train()
        print('Epoch {2} : Training loss {0:.8f} and valid loss : {1:.8f} :  '.format(running_loss/len(inputs),valid_loss, e))
   
        print ('Epoch {2} : valid accuracy :{0:.8f} with total prob : {1:.8f} '.format(accuracy*100  ,propabilities, e))
        print(time.time()-c)
    #print('validation loss with iterations {0}'.format(valid_loss1/len(vinputs) ) )   
        train_losses.append(running_loss/len(inputs))
        valid_losses.append(valid_loss)
        if (valid_loss<valid_loss_min):
            print('validation loss decreased , saving model ({:.8f} ==> {:.8f})'.format(valid_loss_min,valid_loss))
            torch.save(model.state_dict(),'14mod_gru_adam.pth')
            no_learning=0
            valid_loss_min=valid_loss
        else:
            no_learning+=1
        if(no_learning==10):
            no_learning=0
            #model.load_state_dict(torch.load('3mod_temp_5_mlp_b.pth'))

print(time.time()-a)
torch.save(model.state_dict(),'14mod_gru_adam#2.pth')
# Out:
# Epoch  : valid accuracy :54.98524475 with total prob : 26.83136177
# Epoch 0 : Training loss 0.00007702 and valid loss : -0.53376372 :
# Epoch 0 : valid accuracy :53.20169830 with total prob : 97.37738800
# 105.39204668998718
# validation loss decreased , saving model (inf ==> -0.53376372)
# Epoch 1 : Training loss 0.00006935 and valid loss : -0.59506584 :
# Epoch 1 : valid accuracy :59.13636780 with total prob : 93.32366180
# 102.57565665245056
# validation loss decreased , saving model (-0.53376372 ==> -0.59506584)
# Epoch 2 : Training loss 0.00005237 and valid loss : -0.61906178 :
# Epoch 2 : valid accuracy :61.77716064 with total prob : 97.21655273
# 101.87725734710693
# validation loss decreased , saving model (-0.59506584 ==> -0.61906178)
# Epoch 3 : Training loss 0.00005579 and valid loss : -0.67507312 :
# Epoch 3 : valid accuracy :67.32103729 with total prob : 90.92047119
# 101.7626473903656
# validation loss decreased , saving model (-0.61906178 ==> -0.67507312)
# Epoch 4 : Training loss 0.00005557 and valid loss : -0.66446742 :
# Epoch 4 : valid accuracy :67.13304138 with total prob : 98.44702148
# 102.17913603782654
# Epoch 5 : Training loss 0.00005396 and valid loss : -0.66605655 :
# Epoch 5 : valid accuracy :66.35919189 with total prob : 94.05926514
# 102.59918165206909
# Epoch 6 : Training loss 0.00005385 and valid loss : -0.67680155 :
# Epoch 6 : valid accuracy :68.67527008 with total prob : 98.08406067
# 105.16505980491638
# validation loss decreased , saving model (-0.67507312 ==> -0.67680155)
# Epoch 7 : Training loss 0.00004521 and valid loss : -0.84189039 :
# Epoch 7 : valid accuracy :91.72691345 with total prob : 92.42372131
# 101.29302716255188
# validation loss decreased , saving model (-0.67680155 ==> -0.84189039)
# Epoch 8 : Training loss 0.00004614 and valid loss : -0.78418547 :
# Epoch 8 : valid accuracy :74.05826569 with total prob : 87.74421692
# 102.93620681762695
# Epoch 9 : Training loss 0.00003173 and valid loss : -0.78083473 :
# Epoch 9 : valid accuracy :69.91238403 with total prob : 91.55816650
# 101.6848075389862
# Epoch 10 : Training loss 0.00004198 and valid loss : -0.72018170 :
# Epoch 10 : valid accuracy :67.32057953 with total prob : 87.90700531
# 101.6957745552063
# Epoch 11 : Training loss 0.00004256 and valid loss : -0.90910498 :
# Epoch 11 : valid accuracy :91.72851562 with total prob : 99.05052185
# 102.06967353820801
# validation loss decreased , saving model (-0.84189039 ==> -0.90910498)
# Epoch 12 : Training loss 0.00005231 and valid loss : -0.86207842 :
# Epoch 12 : valid accuracy :88.64747620 with total prob : 95.55704498
# 105.67367482185364
# Epoch 13 : Training loss 0.00005477 and valid loss : -0.84210958 :
# Epoch 13 : valid accuracy :94.32395935 with total prob : 89.55818176
# 101.99039769172668
# Epoch 14 : Training loss 0.00003097 and valid loss : -0.72451303 :
# Epoch 14 : valid accuracy :65.01863098 with total prob : 91.86759949
# 100.80337738990784
# Epoch 15 : Training loss 0.00006358 and valid loss : -0.86537434 :
# Epoch 15 : valid accuracy :88.05683136 with total prob : 96.61513519
# 101.83222389221191
# Epoch 16 : Training loss 0.00005052 and valid loss : -0.94237517 :
# Epoch 16 : valid accuracy :94.30459595 with total prob : 99.70727539
# 100.92710947990417
# validation loss decreased , saving model (-0.90910498 ==> -0.94237517)
# Epoch 17 : Training loss 0.00004371 and valid loss : -0.94444787 :
# Epoch 17 : valid accuracy :94.86037445 with total prob : 98.25603485
# 103.87611031532288
# validation loss decreased , saving model (-0.94237517 ==> -0.94444787)
# Epoch 18 : Training loss 0.00002975 and valid loss : -0.67244045 :
# Epoch 18 : valid accuracy :67.15354919 with total prob : 88.39144897
# 105.44025373458862
# Epoch 19 : Training loss 0.00004737 and valid loss : -0.71703597 :
# Epoch 19 : valid accuracy :69.87911224 with total prob : 94.65327454
# 102.21552228927612
# Epoch 20 : Training loss 0.00004738 and valid loss : -0.87377519 :
# Epoch 20 : valid accuracy :89.44638824 with total prob : 94.58016968
# 101.97157144546509
# Epoch 21 : Training loss 0.00004650 and valid loss : -0.91269645 :
# Epoch 21 : valid accuracy :92.76897430 with total prob : 96.76109314
# 101.4773542881012
# Epoch 22 : Training loss 0.00004100 and valid loss : -0.93228895 :
# Epoch 22 : valid accuracy :94.26995850 with total prob : 97.69148254
# 102.21800255775452
# Epoch 23 : Training loss 0.00005822 and valid loss : -0.61688500 :
# Epoch 23 : valid accuracy :61.17923355 with total prob : 90.15567017
# 111.79496598243713
# Epoch 24 : Training loss 0.00009624 and valid loss : -0.92117385 :
# Epoch 24 : valid accuracy :91.57196808 with total prob : 95.95043945
# 104.20558381080627
# Epoch 25 : Training loss 0.00002849 and valid loss : -0.65937927 :
# Epoch 25 : valid accuracy :62.56536865 with total prob : 95.29418182
# 102.68880891799927
# Epoch 26 : Training loss 0.00006389 and valid loss : -0.66578180 :
# Epoch 26 : valid accuracy :66.90494537 with total prob : 96.63316345
# 103.37063598632812
# Epoch 27 : Training loss 0.00004863 and valid loss : -0.92449622 :
# Epoch 27 : valid accuracy :94.16559601 with total prob : 97.55067444
# 101.17129516601562
# Epoch 28 : Training loss 0.00005427 and valid loss : -0.89284451 :
# Epoch 28 : valid accuracy :89.33905792 with total prob : 99.54271698
# 102.10941100120544
# Epoch 29 : Training loss 0.00003774 and valid loss : -0.92799545 :
# Epoch 29 : valid accuracy :92.98020935 with total prob : 98.60562897
# 117.22086215019226
# Epoch 30 : Training loss 0.00004136 and valid loss : -0.84857290 :
# Epoch 30 : valid accuracy :84.37808228 with total prob : 97.98144531
# 103.25374054908752
# Epoch 31 : Training loss 0.00004347 and valid loss : -0.89141233 :
# Epoch 31 : valid accuracy :87.65395355 with total prob : 94.72645569
# 102.93350315093994
# Epoch 32 : Training loss 0.00003337 and valid loss : -0.93416545 :
# Epoch 32 : valid accuracy :94.18929291 with total prob : 99.07756042
# 102.70772242546082
# Epoch 33 : Training loss 0.00004743 and valid loss : -0.83022054 :
# Epoch 33 : valid accuracy :89.42861938 with total prob : 93.58990479
# 103.40126776695251
# Epoch 34 : Training loss 0.00006851 and valid loss : -0.93623844 :
# Epoch 34 : valid accuracy :94.16080475 with total prob : 99.42172241
# 102.01432538032532
# Epoch 35 : Training loss 0.00006425 and valid loss : -0.94299030 :
# Epoch 35 : valid accuracy :94.32077026 with total prob : 99.95055389
# 114.14556241035461
# Epoch 36 : Training loss 0.00005129 and valid loss : -0.63548517 :
# Epoch 36 : valid accuracy :65.03890991 with total prob : 88.30099487
# 103.11978793144226
# Epoch 37 : Training loss 0.00006049 and valid loss : -0.90750836 :
# Epoch 37 : valid accuracy :91.27710724 with total prob : 98.96778107
# 103.13469099998474
# Epoch 38 : Training loss 0.00004818 and valid loss : -0.94228575 :
# Epoch 38 : valid accuracy :94.32237244 with total prob : 99.77524567
# 103.02970814704895
# Epoch 39 : Training loss 0.00003598 and valid loss : -0.89823789 :
# Epoch 39 : valid accuracy :89.83855438 with total prob : 99.67276764
# 102.77079916000366
# Epoch 40 : Training loss 0.00003864 and valid loss : -0.89259425 :
# Epoch 40 : valid accuracy :91.73261261 with total prob : 95.86018372
# 102.19732666015625
# Epoch 41 : Training loss 0.00005367 and valid loss : -0.65492164 :
# Epoch 41 : valid accuracy :65.31189728 with total prob : 96.97335052
# 112.42070031166077
# Epoch 42 : Training loss 0.00007900 and valid loss : -0.92794381 :
# Epoch 42 : valid accuracy :93.41703796 with total prob : 97.49089813
# 102.70127248764038
# Epoch 43 : Training loss 0.00004176 and valid loss : -0.93886687 :
# Epoch 43 : valid accuracy :94.32442474 with total prob : 99.37950897
# 102.38721632957458
# Epoch 44 : Training loss 0.00005936 and valid loss : -0.90139309 :
# Epoch 44 : valid accuracy :90.56432343 with total prob : 99.00178528
# 100.17365717887878
# Epoch 45 : Training loss 0.00003697 and valid loss : -0.93258869 :
# Epoch 45 : valid accuracy :95.60619354 with total prob : 97.22032928
# 100.80693435668945
# Epoch 46 : Training loss 0.00003358 and valid loss : -0.91677912 :
# Epoch 46 : valid accuracy :91.73102570 with total prob : 99.71699524
# 100.27977442741394
# Epoch 47 : Training loss 0.00005529 and valid loss : -0.94127013 :
# Epoch 47 : valid accuracy :94.32077026 with total prob : 99.44546509
# 111.90709662437439
# Epoch 48 : Training loss 0.00003688 and valid loss : -0.92828956 :
# Epoch 48 : valid accuracy :92.25261688 with total prob : 97.03655243
# 101.41432785987854
# Epoch 49 : Training loss 0.00004234 and valid loss : -0.93320847 :
# Epoch 49 : valid accuracy :94.18336487 with total prob : 98.06920624
# 103.07492661476135
# Epoch 50 : Training loss 0.00004099 and valid loss : -0.94295416 :
# Epoch 50 : valid accuracy :94.32395935 with total prob : 99.94313812
# 102.9309754371643
# Epoch 51 : Training loss 0.00005976 and valid loss : -0.94078579 :
# Epoch 51 : valid accuracy :94.32487488 with total prob : 99.32431793
# 102.04552483558655
# Epoch 52 : Training loss 0.00005306 and valid loss : -0.91988196 :
# Epoch 52 : valid accuracy :94.32487488 with total prob : 97.53523254
# 102.45790386199951
# Epoch 53 : Training loss 0.00003903 and valid loss : -0.94892527 :
# Epoch 53 : valid accuracy :96.19523621 with total prob : 96.81596375
# 113.83588767051697
# validation loss decreased , saving model (-0.94444787 ==> -0.94892527)
# Epoch 54 : Training loss 0.00003163 and valid loss : -0.94143369 :
# Epoch 54 : valid accuracy :94.32487488 with total prob : 99.52881622
# 103.4750611782074
# Epoch 55 : Training loss 0.00004687 and valid loss : -0.93767966 :
# Epoch 55 : valid accuracy :94.31826782 with total prob : 99.39283752
# 102.4701509475708
# Epoch 56 : Training loss 0.00004229 and valid loss : -0.93924088 :
# Epoch 56 : valid accuracy :94.30300140 with total prob : 99.31372070
# 101.77015614509583
# Epoch 57 : Training loss 0.00004000 and valid loss : -0.94175015 :
# Epoch 57 : valid accuracy :94.31917572 with total prob : 99.83062744
# 101.99533414840698
# Epoch 58 : Training loss 0.00003473 and valid loss : -0.93913193 :
# Epoch 58 : valid accuracy :94.31986237 with total prob : 99.22517395
# 101.65439224243164
# Epoch 59 : Training loss 0.00005119 and valid loss : -0.92919867 :
# Epoch 59 : valid accuracy :94.11067963 with total prob : 98.41493988
# 112.54452252388
# Epoch 60 : Training loss 0.00003731 and valid loss : -0.93781157 :
# Epoch 60 : valid accuracy :94.32168579 with total prob : 98.83309937
# 100.74918675422668
# Epoch 61 : Training loss 0.00003387 and valid loss : -0.70283019 :
# Epoch 61 : valid accuracy :69.91693878 with total prob : 99.20218658
# 102.44300198554993
# Epoch 62 : Training loss 0.00004554 and valid loss : -0.94301874 :
# Epoch 62 : valid accuracy :94.32282257 with total prob : 99.96250153
# 100.51526713371277
# Epoch 63 : Training loss 0.00004804 and valid loss : -0.93149540 :
# Epoch 63 : valid accuracy :94.31188965 with total prob : 97.95949554
# 100.6144757270813
# Epoch 64 : Training loss 0.00003706 and valid loss : -0.86282376 :
# Epoch 64 : valid accuracy :94.32395935 with total prob : 91.28792572
# 101.11179041862488
# Epoch 65 : Training loss 0.00003652 and valid loss : -0.84965851 :
# Epoch 65 : valid accuracy :89.45003510 with total prob : 89.95758820
# 111.71216654777527
# Epoch 66 : Training loss 0.00004406 and valid loss : -0.92269697 :
# Epoch 66 : valid accuracy :94.32395935 with total prob : 97.08904266
# 103.21321320533752
# Epoch 67 : Training loss 0.00003379 and valid loss : -0.68727303 :
# Epoch 67 : valid accuracy :65.04300690 with total prob : 93.71570587
# 102.52846646308899
# Epoch 68 : Training loss 0.00003524 and valid loss : -0.90246560 :
# Epoch 68 : valid accuracy :91.73170471 with total prob : 97.80601501
# 102.85713052749634
# Epoch 69 : Training loss 0.00004541 and valid loss : -0.90776566 :
# Epoch 69 : valid accuracy :91.53299713 with total prob : 98.73238373
# 102.87683081626892
# Epoch 70 : Training loss 0.00002839 and valid loss : -0.93985873 :
# Epoch 70 : valid accuracy :94.32487488 with total prob : 99.19134521
# 105.29740452766418
# Epoch 71 : Training loss 0.00003923 and valid loss : -0.89638446 :
# Epoch 71 : valid accuracy :89.28300476 with total prob : 97.09397888
# 117.37947916984558
# Epoch 72 : Training loss 0.00004843 and valid loss : -0.94310067 :
# Epoch 72 : valid accuracy :94.32487488 with total prob : 99.96155548
# 101.92769837379456
# Epoch 73 : Training loss 0.00004663 and valid loss : -0.86981433 :
# Epoch 73 : valid accuracy :88.96102142 with total prob : 94.64035797
# 102.60064125061035
# Epoch 74 : Training loss 0.00003605 and valid loss : -0.94236348 :
# Epoch 74 : valid accuracy :94.32487488 with total prob : 99.77363586
# 102.12075543403625
# Epoch 75 : Training loss 0.00003570 and valid loss : -0.93387639 :
# Epoch 75 : valid accuracy :94.10565948 with total prob : 98.57898712
# 103.2201988697052
# Epoch 76 : Training loss 0.00003475 and valid loss : -0.94154931 :
# Epoch 76 : valid accuracy :94.31120300 with total prob : 99.57786560
# 101.6829423904419
# Epoch 77 : Training loss 0.00003810 and valid loss : -0.91683748 :
# Epoch 77 : valid accuracy :91.73261261 with total prob : 99.59108734
# 113.38638925552368
# Epoch 78 : Training loss 0.00003366 and valid loss : -0.93906031 :
# Epoch 78 : valid accuracy :94.32487488 with total prob : 98.90774536
# 101.8549451828003
# Epoch 79 : Training loss 0.00003591 and valid loss : -0.93335677 :
# Epoch 79 : valid accuracy :93.63761902 with total prob : 97.33418274
# 102.46115207672119
# Epoch 80 : Training loss 0.00006217 and valid loss : -0.93863476 :
# Epoch 80 : valid accuracy :94.32442474 with total prob : 98.84700012
# 102.71469140052795
# Epoch 81 : Training loss 0.00003917 and valid loss : -0.93087886 :
# Epoch 81 : valid accuracy :94.32442474 with total prob : 96.58618164
# 102.9996554851532
# Epoch 82 : Training loss 0.00004027 and valid loss : -0.94168900 :
# Epoch 82 : valid accuracy :94.32395935 with total prob : 99.60095215
# 110.62014842033386
# Epoch 83 : Training loss 0.00004213 and valid loss : -0.94094656 :
# Epoch 83 : valid accuracy :94.32395935 with total prob : 99.38043213
# 111.10185766220093
# Epoch 84 : Training loss 0.00003949 and valid loss : -0.65341811 :
# Epoch 84 : valid accuracy :65.14350128 with total prob : 99.34900665
# 102.1903178691864
# Epoch 85 : Training loss 0.00005304 and valid loss : -0.90128153 :
# Epoch 85 : valid accuracy :94.32442474 with total prob : 95.80203247
# 101.0371503829956
# Epoch 86 : Training loss 0.00003807 and valid loss : -0.71416779 :
# Epoch 86 : valid accuracy :67.32422638 with total prob : 95.55698395
# 103.48856925964355
# Epoch 87 : Training loss 0.00005021 and valid loss : -0.91746725 :
# Epoch 87 : valid accuracy :91.73261261 with total prob : 99.06764221
# 100.9407753944397
# Epoch 88 : Training loss 0.00004082 and valid loss : -0.93001775 :
# Epoch 88 : valid accuracy :94.32487488 with total prob : 97.69542694
# 117.17165327072144
# Epoch 89 : Training loss 0.00004570 and valid loss : -0.94297334 :
# Epoch 89 : valid accuracy :94.32487488 with total prob : 99.94351959
# 106.0138475894928
# Epoch 90 : Training loss 0.00004970 and valid loss : -0.93833160 :
# Epoch 90 : valid accuracy :94.32487488 with total prob : 98.68548584
# 101.78292632102966
# Epoch 91 : Training loss 0.00004106 and valid loss : -0.80304201 :
# Epoch 91 : valid accuracy :91.73261261 with total prob : 88.15421295
# 101.34026050567627
# Epoch 92 : Training loss 0.00004928 and valid loss : -0.83452726 :
# Epoch 92 : valid accuracy :93.99263763 with total prob : 87.82835388
# 101.07393598556519
# Epoch 93 : Training loss 0.00005737 and valid loss : -0.93319502 :
# Epoch 93 : valid accuracy :94.28044128 with total prob : 97.44962311
# 103.4026689529419
# Epoch 94 : Training loss 0.00004214 and valid loss : -0.74107942 :
# Epoch 94 : valid accuracy :67.32467651 with total prob : 93.20304108
# 118.48550128936768
# Epoch 95 : Training loss 0.00005273 and valid loss : -0.92870165 :
# Epoch 95 : valid accuracy :91.73261261 with total prob : 96.86164856
# 101.19755983352661
# Epoch 96 : Training loss 0.00004270 and valid loss : -0.93683683 :
# Epoch 96 : valid accuracy :94.32487488 with total prob : 99.33061218
# 100.70444178581238
# Epoch 97 : Training loss 0.00005254 and valid loss : -0.94303338 :
# Epoch 97 : valid accuracy :94.32487488 with total prob : 99.92916107
# 101.43605995178223
# Epoch 98 : Training loss 0.00004816 and valid loss : -0.92179782 :
# Epoch 98 : valid accuracy :92.15417480 with total prob : 99.13274384
# 101.15647315979004
# Epoch 99 : Training loss 0.00005372 and valid loss : -0.94271982 :
# Epoch 99 : valid accuracy :94.32487488 with total prob : 99.84715271
# 101.57291626930237
# Epoch 100 : Training loss 0.00005052 and valid loss : -0.93169550 :
# Epoch 100 : valid accuracy :94.19248199 with total prob : 97.22921753
# 101.1460793018341
# Epoch 101 : Training loss 0.00003575 and valid loss : -0.81011547 :
# Epoch 101 : valid accuracy :87.72891998 with total prob : 91.42838287
# 101.69862461090088
# Epoch 102 : Training loss 0.00004190 and valid loss : -0.92974860 :
# Epoch 102 : valid accuracy :93.63306427 with total prob : 96.77672577
# 101.22096419334412
# Epoch 103 : Training loss 0.00004094 and valid loss : -0.90091133 :
# Epoch 103 : valid accuracy :94.32328033 with total prob : 95.75802612
# 102.17077612876892
# Epoch 104 : Training loss 0.00003993 and valid loss : -0.92618617 :
# Epoch 104 : valid accuracy :92.77307129 with total prob : 98.19807434
# 101.86066102981567
# Epoch 105 : Training loss 0.00004121 and valid loss : -0.92998866 :
# Epoch 105 : valid accuracy :93.18369293 with total prob : 98.83572388
# 101.32269835472107
# Epoch 106 : Training loss 0.00005065 and valid loss : -0.85522932 :
# Epoch 106 : valid accuracy :90.01948547 with total prob : 91.16200256
# 101.97192931175232
# Epoch 107 : Training loss 0.00004818 and valid loss : -0.91487420 :
# Epoch 107 : valid accuracy :94.24238586 with total prob : 97.20106506
# 102.22016620635986
# Epoch 108 : Training loss 0.00003460 and valid loss : -0.95591944 :
# Epoch 108 : valid accuracy :95.72741699 with total prob : 99.65920258
# 102.60870170593262
# validation loss decreased , saving model (-0.94892527 ==> -0.95591944)
# Epoch 109 : Training loss 0.00004018 and valid loss : -0.94345404 :
# Epoch 109 : valid accuracy :94.32328033 with total prob : 98.61691284
# 103.61644887924194
# Epoch 110 : Training loss 0.00003284 and valid loss : -0.94050162 :
# Epoch 110 : valid accuracy :94.32328033 with total prob : 99.25462341
# 103.07177114486694
# Epoch 111 : Training loss 0.00004737 and valid loss : -0.94125822 :
# Epoch 111 : valid accuracy :94.32487488 with total prob : 99.46870422
# 102.30657601356506
# Epoch 112 : Training loss 0.00003741 and valid loss : -0.93806492 :
# Epoch 112 : valid accuracy :94.32487488 with total prob : 98.61077118
# 116.87253427505493
# Epoch 113 : Training loss 0.00003875 and valid loss : -0.93978735 :
# Epoch 113 : valid accuracy :94.12525940 with total prob : 99.63385773
# 107.15745663642883
# Epoch 114 : Training loss 0.00003620 and valid loss : -0.94322841 :
# Epoch 114 : valid accuracy :94.32487488 with total prob : 99.98293304
# 107.58726906776428
# Epoch 115 : Training loss 0.00004096 and valid loss : -0.95162870 :
# Epoch 115 : valid accuracy :95.78666687 with total prob : 98.95654297
# 106.14856171607971
# Epoch 116 : Training loss 0.00003334 and valid loss : -0.93754651 :
# Epoch 116 : valid accuracy :94.32556152 with total prob : 98.62776184
# 104.35073828697205
# Epoch 117 : Training loss 0.00003717 and valid loss : -0.91656442 :
# Epoch 117 : valid accuracy :94.32487488 with total prob : 97.22267151
# 104.74895739555359
# Epoch 118 : Training loss 0.00005619 and valid loss : -0.78952438 :
# Epoch 118 : valid accuracy :67.32467651 with total prob : 87.79647064
# 119.55208015441895
# Epoch 119 : Training loss 0.00003800 and valid loss : -0.94306100 :
# Epoch 119 : valid accuracy :94.32487488 with total prob : 99.94935608
# 105.23774862289429
# Epoch 120 : Training loss 0.00005420 and valid loss : -0.95057569 :
# Epoch 120 : valid accuracy :95.54307556 with total prob : 99.41089630
# 103.7623941898346
# Epoch 121 : Training loss 0.00004652 and valid loss : -0.94245955 :
# Epoch 121 : valid accuracy :94.32533264 with total prob : 99.74427032
# 103.88413667678833
# Epoch 122 : Training loss 0.00002897 and valid loss : -0.93109745 :
# Epoch 122 : valid accuracy :92.88860321 with total prob : 97.25069427
# 103.21736693382263
# Epoch 123 : Training loss 0.00003346 and valid loss : -0.94182851 :
# Epoch 123 : valid accuracy :94.32487488 with total prob : 99.79592896
# 103.56852698326111
# Epoch 124 : Training loss 0.00004115 and valid loss : -0.94141357 :
# Epoch 124 : valid accuracy :94.31439972 with total prob : 99.49882507
# 103.93648338317871
# Epoch 125 : Training loss 0.00006614 and valid loss : -0.94342152 :
# Epoch 125 : valid accuracy :94.32487488 with total prob : 99.96497345
# 103.70118689537048
# Epoch 126 : Training loss 0.00007036 and valid loss : -0.81799632 :
# Epoch 126 : valid accuracy :75.92657471 with total prob : 89.49592590
# 103.37421345710754
# Epoch 127 : Training loss 0.00005663 and valid loss : -0.72267337 :
# Epoch 127 : valid accuracy :69.91693878 with total prob : 97.59696198
# 103.07239508628845
# Epoch 128 : Training loss 0.00004720 and valid loss : -0.94089488 :
# Epoch 128 : valid accuracy :94.32487488 with total prob : 99.47380066
# 102.32293367385864
# Epoch 129 : Training loss 0.00004814 and valid loss : -0.93151720 :
# Epoch 129 : valid accuracy :94.30983734 with total prob : 96.74074554
# 102.11283469200134
# Epoch 130 : Training loss 0.00003386 and valid loss : -0.67326911 :
# Epoch 130 : valid accuracy :67.32467651 with total prob : 99.99755859
# 102.49972248077393
# Epoch 131 : Training loss 0.00004686 and valid loss : -0.90964272 :
# Epoch 131 : valid accuracy :94.32646942 with total prob : 95.53649139
# 101.67239665985107
# Epoch 132 : Training loss 0.00003515 and valid loss : -0.92495787 :
# Epoch 132 : valid accuracy :94.32487488 with total prob : 96.25120544
# 100.62643003463745
# Epoch 133 : Training loss 0.00003815 and valid loss : -0.92811418 :
# Epoch 133 : valid accuracy :93.00983429 with total prob : 96.63235474
# 102.9049620628357
# Epoch 134 : Training loss 0.00003302 and valid loss : -0.93361249 :
# Epoch 134 : valid accuracy :94.32487488 with total prob : 97.64506531
# 103.69943070411682
# Epoch 135 : Training loss 0.00004508 and valid loss : -0.69884961 :
# Epoch 135 : valid accuracy :69.91693878 with total prob : 99.30267334
# 103.18303728103638
# Epoch 136 : Training loss 0.00004703 and valid loss : -0.90605410 :
# Epoch 136 : valid accuracy :94.04960632 with total prob : 95.76951599
# 102.72574758529663
# Epoch 137 : Training loss 0.00003075 and valid loss : -0.79172895 :
# Epoch 137 : valid accuracy :76.07241821 with total prob : 91.17530060
# 103.71554493904114
# Epoch 138 : Training loss 0.00004882 and valid loss : -0.92169412 :
# Epoch 138 : valid accuracy :92.16534424 with total prob : 99.36227417
# 103.15534138679504
# Epoch 139 : Training loss 0.00004418 and valid loss : -0.94315212 :
# Epoch 139 : valid accuracy :94.32487488 with total prob : 99.98829651
# 103.6304543018341
# Epoch 140 : Training loss 0.00007228 and valid loss : -0.91740171 :
# Epoch 140 : valid accuracy :91.73261261 with total prob : 99.93596649
# 103.52256536483765
# Epoch 141 : Training loss 0.00006333 and valid loss : -0.78943058 :
# Epoch 141 : valid accuracy :76.63480377 with total prob : 90.40478516
# 102.69451785087585
# Epoch 142 : Training loss 0.00003827 and valid loss : -0.93834711 :
# Epoch 142 : valid accuracy :94.32487488 with total prob : 99.50908661
# 102.16476368904114
# Epoch 143 : Training loss 0.00005442 and valid loss : -0.93727051 :
# Epoch 143 : valid accuracy :94.32487488 with total prob : 98.50440979
# 103.46426153182983
# Epoch 144 : Training loss 0.00004457 and valid loss : -0.94450462 :
# Epoch 144 : valid accuracy :94.35017395 with total prob : 99.83052826
# 103.72164988517761
# Epoch 145 : Training loss 0.00008200 and valid loss : -0.67779132 :
# Epoch 145 : valid accuracy :67.53751373 with total prob : 98.84256744
# 115.23421692848206
# Epoch 146 : Training loss 0.00011727 and valid loss : -0.94262812 :
# Epoch 146 : valid accuracy :94.32487488 with total prob : 99.83087921
# 103.72572135925293
# Epoch 147 : Training loss 0.00004995 and valid loss : -0.91698346 :
# Epoch 147 : valid accuracy :91.70983124 with total prob : 99.89816284
# 104.29911637306213
# Epoch 148 : Training loss 0.00004189 and valid loss : -0.84504824 :
# Epoch 148 : valid accuracy :94.32487488 with total prob : 90.11768341
# 103.5488452911377
# Epoch 149 : Training loss 0.00005620 and valid loss : -0.94191475 :
# Epoch 149 : valid accuracy :94.32487488 with total prob : 99.76558685
# 103.95661664009094
# Epoch 150 : Training loss 0.00004593 and valid loss : -0.76590450 :
# Epoch 150 : valid accuracy :76.14647675 with total prob : 95.44107056
# 102.4713523387909
# Epoch 151 : Training loss 0.00005202 and valid loss : -0.91662457 :
# Epoch 151 : valid accuracy :91.73284149 with total prob : 99.91795349
# 116.09617495536804
# Epoch 152 : Training loss 0.00005046 and valid loss : -0.94305370 :
# Epoch 152 : valid accuracy :94.32487488 with total prob : 99.97773743
# 103.39707946777344
# Epoch 153 : Training loss 0.00003330 and valid loss : -0.67392993 :
# Epoch 153 : valid accuracy :67.32308960 with total prob : 99.81347656
# 103.13036704063416
# Epoch 154 : Training loss 0.00005206 and valid loss : -0.87301188 :
# Epoch 154 : valid accuracy :87.26612091 with total prob : 98.74903870
# 103.39324355125427
# Epoch 155 : Training loss 0.00003942 and valid loss : -0.69962709 :
# Epoch 155 : valid accuracy :69.91693878 with total prob : 99.93709564
# 103.59176468849182
# Epoch 156 : Training loss 0.00006153 and valid loss : -0.91833826 :
# Epoch 156 : valid accuracy :92.03295135 with total prob : 98.67037201
# 103.26165223121643
# Epoch 157 : Training loss 0.00004081 and valid loss : -0.92645601 :
# Epoch 157 : valid accuracy :93.65288544 with total prob : 97.06607819
# 115.19987487792969
# Epoch 158 : Training loss 0.00003503 and valid loss : -0.78378816 :
# Epoch 158 : valid accuracy :79.43830109 with total prob : 96.54152679
# 102.77557873725891
# Epoch 159 : Training loss 0.00004422 and valid loss : -0.69101553 :
# Epoch 159 : valid accuracy :69.79844666 with total prob : 97.75950623
# 103.15837597846985
# Epoch 160 : Training loss 0.00005199 and valid loss : -0.94177485 :
# Epoch 160 : valid accuracy :94.32487488 with total prob : 99.55497742
# 104.16209363937378
# Epoch 161 : Training loss 0.00003696 and valid loss : -0.94217576 :
# Epoch 161 : valid accuracy :94.32487488 with total prob : 99.80268860
# 102.63674139976501
# Epoch 162 : Training loss 0.00005265 and valid loss : -0.91735188 :
# Epoch 162 : valid accuracy :91.73261261 with total prob : 99.99316406
# 103.23273229598999
# Epoch 163 : Training loss 0.00003314 and valid loss : -0.68458509 :
# Epoch 163 : valid accuracy :68.57682800 with total prob : 98.70858002
# 114.78844594955444
# Epoch 164 : Training loss 0.00007384 and valid loss : -0.94204880 :
# Epoch 164 : valid accuracy :94.32487488 with total prob : 99.71952057
# 103.57750868797302
# Epoch 165 : Training loss 0.00004393 and valid loss : -0.94079438 :
# Epoch 165 : valid accuracy :94.32487488 with total prob : 99.29832458
# 103.69529056549072
# Epoch 166 : Training loss 0.00007234 and valid loss : -0.92894354 :
# Epoch 166 : valid accuracy :93.31039429 with total prob : 98.79181671
# 103.39710712432861
# Epoch 167 : Training loss 0.00005434 and valid loss : -0.94256865 :
# Epoch 167 : valid accuracy :94.32487488 with total prob : 99.79313660
# 103.41175603866577
# Epoch 168 : Training loss 0.00004064 and valid loss : -0.67325016 :
# Epoch 168 : valid accuracy :67.32491302 with total prob : 99.99588013
# 117.77760410308838
# Epoch 169 : Training loss 0.00011758 and valid loss : -0.92244116 :
# Epoch 169 : valid accuracy :94.02773285 with total prob : 97.59972382
# 103.69245672225952
# Epoch 170 : Training loss 0.00004086 and valid loss : -0.70042194 :
# Epoch 170 : valid accuracy :69.70980835 with total prob : 98.49908447
# 103.96555614471436
# Epoch 171 : Training loss 0.00009814 and valid loss : -0.88441541 :
# Epoch 171 : valid accuracy :89.94952393 with total prob : 95.66618347
# 103.07278943061829
# Epoch 172 : Training loss 0.00004001 and valid loss : -0.91559620 :
# Epoch 172 : valid accuracy :91.73261261 with total prob : 96.24575043
# 106.27624845504761
# Epoch 173 : Training loss 0.00004558 and valid loss : -0.67324824 :
# Epoch 173 : valid accuracy :67.32467651 with total prob : 99.99971771
# 101.96772718429565
# Epoch 174 : Training loss 0.00005356 and valid loss : -0.68470088 :
# Epoch 174 : valid accuracy :68.25051880 with total prob : 98.69244385
# 120.3171718120575
# Epoch 175 : Training loss 0.00005903 and valid loss : -0.83752163 :
# Epoch 175 : valid accuracy :83.74232483 with total prob : 94.21701050
# 102.87171268463135
# Epoch 176 : Training loss 0.00003801 and valid loss : -0.72949917 :
# Epoch 176 : valid accuracy :67.32467651 with total prob : 94.37158966
# 103.47391819953918
# Epoch 177 : Training loss 0.00003512 and valid loss : -0.94302369 :
# Epoch 177 : valid accuracy :94.32487488 with total prob : 99.96859741
# 103.06419682502747
# Epoch 178 : Training loss 0.00005453 and valid loss : -0.67427956 :
# Epoch 178 : valid accuracy :67.32467651 with total prob : 99.71953583
# 102.6758382320404
# Epoch 179 : Training loss 0.00005033 and valid loss : -0.67664933 :
# Epoch 179 : valid accuracy :67.55072784 with total prob : 99.22764587
# 104.29068946838379
# Epoch 180 : Training loss 0.00007732 and valid loss : -0.91537344 :
# Epoch 180 : valid accuracy :91.73261261 with total prob : 99.79553986
# 115.65368700027466
# Epoch 181 : Training loss 0.00003603 and valid loss : -0.87639299 :
# Epoch 181 : valid accuracy :91.73261261 with total prob : 95.90667725
# 103.73622250556946
# Epoch 182 : Training loss 0.00004655 and valid loss : -0.83500475 :
# Epoch 182 : valid accuracy :94.32487488 with total prob : 87.29341888
# 103.89652633666992
# Epoch 183 : Training loss 0.00003833 and valid loss : -0.67327081 :
# Epoch 183 : valid accuracy :67.32467651 with total prob : 99.98908997
# 103.71921396255493
# Epoch 184 : Training loss 0.00006120 and valid loss : -0.93696643 :
# Epoch 184 : valid accuracy :94.32442474 with total prob : 99.37208557
# 104.17361402511597
# Epoch 185 : Training loss 0.00007244 and valid loss : -0.68312022 :
# Epoch 185 : valid accuracy :67.32467651 with total prob : 97.26129150
# 103.77994680404663
# Epoch 186 : Training loss 0.00005238 and valid loss : -0.78711868 :
# Epoch 186 : valid accuracy :74.33467865 with total prob : 91.33512115
# 115.85656905174255
# Epoch 187 : Training loss 0.00004586 and valid loss : -0.89041682 :
# Epoch 187 : valid accuracy :91.73261261 with total prob : 96.98756409
# 102.58456659317017
# Epoch 188 : Training loss 0.00003813 and valid loss : -0.91705370 :
# Epoch 188 : valid accuracy :91.73239136 with total prob : 99.43547821
# 103.44904708862305
# Epoch 189 : Training loss 0.00004437 and valid loss : -0.93746148 :
# Epoch 189 : valid accuracy :94.32487488 with total prob : 99.16536713
# 102.01393723487854
# Epoch 190 : Training loss 0.00006400 and valid loss : -0.67772441 :
# Epoch 190 : valid accuracy :67.76538849 with total prob : 99.68090057
# 101.51392388343811
# Epoch 191 : Training loss 0.00009917 and valid loss : -0.92027068 :
# Epoch 191 : valid accuracy :91.73261261 with total prob : 99.16695404
# 102.52470779418945
# Epoch 192 : Training loss 0.00005857 and valid loss : -0.67330783 :
# Epoch 192 : valid accuracy :67.32467651 with total prob : 99.99219513
# 114.24779319763184
# Epoch 193 : Training loss 0.00007397 and valid loss : -0.91067258 :
# Epoch 193 : valid accuracy :91.08477783 with total prob : 99.90416718
# 102.3876428604126
# Epoch 194 : Training loss 0.00004008 and valid loss : -0.91682107 :
# Epoch 194 : valid accuracy :91.73261261 with total prob : 99.70241547
# 102.74250435829163
# Epoch 195 : Training loss 0.00004453 and valid loss : -0.93069180 :
# Epoch 195 : valid accuracy :94.32487488 with total prob : 98.42726898
# 103.6245629787445
# Epoch 196 : Training loss 0.00004296 and valid loss : -0.63463775 :
# Epoch 196 : valid accuracy :63.22710419 with total prob : 99.75159454
# 103.7531054019928
# Epoch 197 : Training loss 0.00004057 and valid loss : -0.94215109 :
# Epoch 197 : valid accuracy :94.32442474 with total prob : 99.79808044
# 104.53966522216797
# Epoch 198 : Training loss 0.00004678 and valid loss : -0.69445379 :
# Epoch 198 : valid accuracy :65.25515747 with total prob : 86.61054230
# 115.82665514945984
# Epoch 199 : Training loss 0.00006257 and valid loss : -0.93149570 :
# Epoch 199 : valid accuracy :94.32487488 with total prob : 96.87126160
# 103.93864345550537
# 20895.657452583313

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 

#test_losses_scaled = scaler.fit_transform(test_losses)



Tr=np.array(train_losses)
Te=np.array(valid_losses)

Tr=np.reshape(Tr, (len(Tr),1))
Te=np.reshape(Te, (len(Te),1))

# fit on training data column
scale = StandardScaler().fit(Tr)
tain_losses = scale.transform(Tr)
scale = StandardScaler().fit(Te)
test_losses = scale.transform(Te)




from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 

#test_losses_scaled = scaler.fit_transform(test_losses)
plt.ylim([-1,1])

plt.plot(tain_losses, label='Train loss')
plt.plot(test_losses, label='valid loss')
plt.legend(frameon=False)
